# %% [markdown]
# # 1.

# %%
import numpy as np

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

circuit = QuantumCircuit(3, 1)
circuit.h([0,1,2])

circuit.z(2)

circuit.measure(1, 0)

circuit.draw('mpl')

# %%
# Ejecutar el circuito en el simulador
backend = Aer.get_backend('qasm_simulator')
results = execute(circuit, backend, shots=1000).result()
counts = results.get_counts()
plot_histogram(counts)

# %% [markdown]
# ## 2.
# Tiene como minimo  3 quibits independietes  (las graficas siguienes las use para guiarme y ver como es la qsphere para 3 quibits)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

circuit_2qubits = QuantumCircuit(2)
circuit_2qubits.h(0)
circuit_2qubits.cx(0, 1)
state_2qubits = Statevector.from_instruction(circuit_2qubits)
plot_state_qsphere(state_2qubits)

# %%
circuit_3qubits = QuantumCircuit(3)
state_3qubits = Statevector.from_instruction(circuit_3qubits)
plot_state_qsphere(state_3qubits)

# %% [markdown]
# # 3.

# %%
from qiskit import QuantumCircuit, Aer, transpile
from qiskit.visualization import plot_histogram
from qiskit.providers.aer import AerSimulator

theta = np.pi
phi = np.pi/2
lambd = 7*np.pi/2

circuit1 = QuantumCircuit(1)

circuit1.u(theta, phi, lambd, 0) 

circuit1.draw('mpl')

# %% [markdown]
# ## 5

# %%
from qiskit import QuantumCircuit


qc = QuantumCircuit(4)


qc.cx(2, 3)  


qc.cx(1, 3)  

qc.cx(0, 3)  


oracle_circuit = qc()
oracle_circuit.qc('mpl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      10 qc.cx(1, 3)
#      12 qc.cx(0, 3)
# ---> 15 oracle_circuit = qc()
#      16 oracle_circuit.qc('mpl')
#
# TypeError: 'QuantumCircuit' object is not callable

# %% [markdown]
# ## 6

# %% [markdown]
# En la construcción más simple posible de un oráculo balanceado, se utiliza la compuerta $CX$, la cual toma como objetivo el $(n+1)$-ésimo qubit del circuito y como control cada uno de los $n$ primeros qubits. Sin embargo, ¿es realmente necesario aplicar $CX$ a todos los $n$ primeros qubits, o podríamos prescindir de algunos y obtener igualmente un oráculo balanceado?
#
# No es realmente necesario aplicar a todos los circuitos la compuerta CX puesto que depende mucho que funcion f(x) es el que uno desea, dependera mucho la aleatoriedad que se quiere dar a la f(x). Para construir un oráculo balanceado usando solo compuertas CX, basta con asegurarse de que la mitad de las posibles entradas x provoquen una inversión en el qubit auxiliar y la otra mitad no. No es necesario que cada qubit individual en la entrada sea usado como un control para una compuerta CX.Esto se menciono en clase
